# %%
import pandas as pd
import json

# %%
filename = "NYC/manhattan-network/split_trips.json"
f = open(filename)
split_trips = json.load(f)
f.close()
#????

# %%
filename = "NYC/manhattan-network/edge_time_matrix.json"
f = open(filename)
edge_time_matrix = json.load(f)
f.close()
#1718*1718 time data (2951524)

# %%
filename = "NYC/manhattan-network/stop2zone.json"
f = open(filename)
stop2zone = json.load(f)
f.close()
# 1718 zone ID

# %%
filename = "NYC/manhattan-network/real_location_matrix.json"
f = open(filename)
real_location_matrix = json.load(f)
f.close()
# 1718 locations

# %%
filename = "NYC/manhattan-network/latlons.json"
f = open(filename)
latlons = json.load(f)
f.close()
# 1718 locations

# %%
filename = "NYC/manhattan-network/manhattan-geo.json"
f = open(filename)
manhattan_geo = json.load(f)
f.close()
# manhattan_geo['features'][0]['geometry']['coordinates']
# 37 district

# %%
filename = "NYC/manhattan-network/location_to_cell.json"
f = open(filename)
location_to_cell = json.load(f)
f.close()
# 1718 locations and cells

# %%
filename = "NYC/manhattan-network/stop_matrix.json"
f = open(filename)
stop_matrix = json.load(f)
f.close()
# 1718 cells

# %%
filename = "NYC/manhattan-network/real_location_matrix.json"
f = open(filename)
real_location_matrix = json.load(f)
f.close()
# 1718 locations

# %%
filename = "NYC/manhattan-network/restrictions.json"
f = open(filename)
restrictions = json.load(f)
f.close()
# ?????
